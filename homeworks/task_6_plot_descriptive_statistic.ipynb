# %% [markdown]
# ## Task Nª 6: Plot histogram of DIC and TA.

# %%
import pandas as pd

def read_csv_file_pandas(file_path):
    """
    Reads a CSV file using pandas and returns a DataFrame.
    
    :param file_path: Path to the CSV file
    :return: pandas DataFrame
    """
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None
    except Exception as e:
        print(f"Error: {e}")
        return None

# %% [markdown]
# ### CHARGE DATAFRAME

# %%
csv_df = read_csv_file_pandas("E:\Folders\Desktop\My_Things\Modelab2025_Course\course_python_rep\Modelab-Python\data\Terminos_lagoon_TA_DIC_2023_RawData.csv")
if csv_df is not None:
    print(csv_df)
# Out:
#      sample       date     estuary   area station layer_depth season  \
# 0    CDL01S   5/3/2020  Candelaria  River   CDL01     Surface    Dry
# 1    CDL01F   5/3/2020  Candelaria  River   CDL01      Bottom    Dry
# 2    CDL02S   5/3/2020  Candelaria  River   CDL02     Surface    Dry
# 3    CDL02F   5/3/2020  Candelaria  River   CDL02      Bottom    Dry
# 4    CDL03S   5/3/2020  Candelaria  River   CDL03     Surface    Dry
# ..      ...        ...         ...    ...     ...         ...    ...
# 101  PLZ07F  10/2/2021    Palizada  Coast   PLZ07      Bottom    Dry
# 102  PLZ08S  10/2/2021    Palizada  Coast   PLZ08     Surface    Dry
# 103  PLZ08F  10/2/2021    Palizada  Coast   PLZ08      Bottom    Dry
# 104  PLZ09S  10/2/2021    Palizada  Coast   PLZ09     Surface    Dry
# 105  PLZ09F  10/2/2021    Palizada  Coast   PLZ09      Bottom    Dry
#
#      chlorophy_microg_l  cond_microsiemens_cm  depth_m  ...  do_mg_l  sal_psu  \
# ...

# %% [markdown]
# ### CHARGE MY PACKAGES

# %%
import matplotlib.pyplot as plt

# PLOT DIC
dic_df = csv_df["dic_micromol_kg"]
plt.hist(dic_df, bins=25)
plt.xlabel("dic_micromol_kg")
plt.ylabel("Frecuency")
plt.show()

# PLOT TA
ta_df = csv_df["ta_micromol_kg"]
plt.hist(ta_df, bins=25)
plt.xlabel("ta_micromol_kg")
plt.ylabel("Frecuency")
plt.show()
